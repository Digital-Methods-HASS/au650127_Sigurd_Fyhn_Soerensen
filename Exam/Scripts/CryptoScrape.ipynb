# %%
import ccxt

# %%
# Initialize the Coinbase API client
client = ccxt.coinbasepro()

# Fetch the daily close prices of Bitcoin for the past 30 days
data = client.fetch_ohlcv('BTC/USD', '1d', limit= 30)

# %%
import yfinance as yf

msft = yf.Ticker("DOGE-USD")

# %%
df = yf.download(
tickers = "DOGE-USD",
period = "1mo",
interval = "1d"
)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2022-12-08  0.095785  0.098874  0.095367  0.098540   0.098540  492909327
# 2022-12-09  0.098538  0.099086  0.096001  0.096662   0.096662  423432535
# 2022-12-10  0.096663  0.097356  0.096258  0.096457   0.096457  242190274
# 2022-12-11  0.096464  0.097093  0.092668  0.092875   0.092875  300470314
# 2022-12-12  0.092872  0.093005  0.087288  0.090258   0.090258  749817261
# 2022-12-13  0.090255  0.094380  0.087718  0.090940   0.090940  766352149
# 2022-12-14  0.090958  0.092240  0.088244  0.088514   0.088514  549320298
# 2022-12-15  0.088508  0.088762  0.084419  0.084722   0.084722  412364377
# 2022-12-16  0.084722  0.086731  0.075388  0.075942   0.075942  699338853
# 2022-12-17  0.075944  0.079375  0.075893  0.079267   0.079267  495547979
# 2022-12-18  0.079262  0.079865  0.077920  0.078641   0.078641  256971055
# 2022-12-19  0.078648  0.079342  0.070913  0.071429   0.071429  581773249
# ...
