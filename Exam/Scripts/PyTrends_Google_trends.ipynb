# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=60)

# %%
kw_list = ["crypto"] # list of keywords to get data 

pytrends.build_payload(kw_list, cat=0, timeframe='all', geo='', gprop='')

pytrends.interest_over_time()
# Out:
#             crypto  isPartial
# date
# 2004-01-01       3      False
# 2004-02-01       3      False
# 2004-03-01       3      False
# 2004-04-01       3      False
# 2004-05-01       3      False
# ...            ...        ...
# 2022-09-01      31      False
# 2022-10-01      27      False
# 2022-11-01      38      False
# 2022-12-01      28      False
# 2023-01-01      28       True
#
# [229 rows x 2 columns]

# %%
data = pytrends.get_historical_interest(kw_list, year_start=2010, month_start=1, day_start=1, hour_start=0, year_end=2022, month_end=12, day_end=31, hour_end=0, cat=0, sleep=0)
# Out:
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# ...

# %%
data.tail()
# Out:
#                      crypto  isPartial
# date
# 2013-12-26 20:00:00      20      False
# 2013-12-26 21:00:00       0      False
# 2013-12-26 22:00:00       0      False
# 2013-12-26 23:00:00      76      False
# 2013-12-27 00:00:00       0      False
